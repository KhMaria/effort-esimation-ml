# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import time
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
import numpy as np 
import time
from mpl_toolkits.mplot3d import Axes3D
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as MSE
from pyGRNN import GRNN #imports the GRNN regressor module
from pyGRNN import feature_selection as FS #imports the GRNN feature selector module
import math
import numpy as np
from numpy.random import seed
seed(1)
import statsmodels.api as sm
import statsmodels.formula.api as smf
import tensorflow
tensorflow.random.set_seed(1)
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Layer
from keras import backend as K
import gc
import numpy as np
from xgboost import XGBRegressor
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from mlens.visualization import corr_X_y, corrmat
from mlens.metrics import make_scorer
from mlens.model_selection import Evaluator
from scipy.stats import uniform, randint
from matplotlib.pyplot import show
# %matplotlib inline
from keras.layers import Dense, Flatten
from keras.models import Sequential
from keras.losses import binary_crossentropy
# Out:
# [MLENS] backend: threading

# %%
pip install pyGRNN

# %%
df = pd.read_csv(r'C:\diploma\datasets\02.desharnais.csv', engine='python')
df.head(5)
# Out:
#    id  Project  TeamExp  ManagerExp  YearEnd  Length  Effort  Transactions  \
# 0   1        1        1           4       85      12    5152           253
# 1   2        2        0           0       86       4    5635           197
# 2   3        3        4           4       85       1     805            40
# 3   4        4        0           0       86       5    3829           200
# 4   5        5        0           0       86       4    2149           140
#
#    Entities  PointsNonAdjust  Adjustment  PointsAjust  Language
# 0        52              305          34          302         1
# 1       124              321          33          315         1
# 2        60              100          18           83         1
# 3       119              319          30          303         1
# 4        94              234          24          208         1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               81 non-null     int64
#  1   Project          81 non-null     int64
#  2   TeamExp          81 non-null     int64
#  3   ManagerExp       81 non-null     int64
#  4   YearEnd          81 non-null     int64
#  5   Length           81 non-null     int64
#  6   Effort           81 non-null     int64
#  7   Transactions     81 non-null     int64
#  8   Entities         81 non-null     int64
#  9   PointsNonAdjust  81 non-null     int64
#  10  Adjustment       81 non-null     int64
#  11  PointsAjust      81 non-null     int64
#  12  Language         81 non-null     int64
# dtypes: int64(13)
# memory usage: 8.4 KB

# %%
#Remove insignificant fields
df = df.drop(columns = ['id', 'Project'])

# %%
#Using Pearson Correlation
plt.figure(figsize=(30,30))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Remove columns with low correlation values
df = df.drop(columns = ['YearEnd', 'TeamExp', 'ManagerExp', 'Language'])

# %%
df.columns.values
# Out:
# array(['Length', 'Effort', 'Transactions', 'Entities', 'PointsNonAdjust',
#        'Adjustment', 'PointsAjust'], dtype=object)

# %%
# SVR

# %%
def launch_model(name,model, X_train, y_train, X_test, y_test):
    start = time.time()
    model.fit(X_train[predictors], y_train)
    y_pred = model.predict(X_test[predictors])
    ypred_train = model.predict(X_train[predictors])
    print ('RMSE', math.sqrt(mean_squared_error(y_test, y_pred)))
    print ('MAE', mean_absolute_error(y_test, y_pred))
    r_2 = round(r2_score(y_test, y_pred), 2)
    print ('R^2', r_2)
    print('Execution time: {0:.2f} sec.'.format(time.time() - start))
    return name + '($R^2={:.3f}$)'.format(r_2), np.array(y_test), y_pred

# %%
def plot(results):

    fig, plts = plt.subplots(nrows=len(results), figsize=(8, 8))
    fig.canvas.set_window_title('Predicting Boston')

    for subplot, (title, y, y_pred) in zip(plts, results):

        subplot.set_xticklabels(())
        subplot.set_yticklabels(())

        subplot.set_ylabel('Precio casa')

        subplot.set_title(title)

        subplot.plot(y, 'b', label='actual')
        subplot.plot(y_pred, 'r', label='predicted')
        
        subplot.fill_between(
            np.arange(0, len(y), 1),
            y,
            y_pred,
            color='r',
            alpha=0.2
        )
        subplot.axvline(len(y) // 2, linestyle='--', color='0', alpha=0.2)
        subplot.legend()
    fig.tight_layout()
    plt.show()
    plt.savefig('plot.png')
    plt.close()

# %%
target = df['Effort']
predictors = ['Length', 'Effort', 'Transactions', 'Entities', 'PointsNonAdjust',
       'Adjustment', 'PointsAjust']
X_train, X_test, y_train, y_test = train_test_split(df, target, test_size=0.2)

# %%
svr_rbf = SVR(kernel='rbf', gamma=0.1)
svr_lineal = SVR(kernel='linear')
lr = LinearRegression()

# %%
results = []
print ('-----------')
print ('SVR - RBF')
print ('-----------')
results.append(launch_model('SVR - RBF', svr_rbf, X_train, y_train, X_test, y_test))
print ('-----------')
print ('SVR - lineal')
print ('-----------')
results.append(launch_model('SVR - lineal', svr_lineal, X_train, y_train, X_test, y_test))
print ('-----------')
print ('Regresion lineal')
print ('-----------')
results.append(launch_model('Regresion lineal', lr, X_train, y_train, X_test, y_test))
# Out:
# -----------
# SVR - RBF
# -----------
# RMSE 3030.392636179636
# MAE 2177.6470588235293
# R^2 -0.02
# Execution time: 0.02 sec.
# -----------
# SVR - lineal
# -----------
# RMSE 0.052686692696273935
# MAE 0.04386009149766992
# R^2 1.0
# Execution time: 0.06 sec.
# -----------
# Regresion lineal
# -----------
# RMSE 1.4322099890797845e-12
# MAE 1.0699937667916803e-12
# R^2 1.0
# Execution time: 0.01 sec.

# %%
plot(results)

# %%
# Random Forests

# %%
labels = np.array(df['Effort'])
df = df.drop('Effort', axis = 1)
feature_list = list(df.columns)
features = np.array(df)

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)

# %%
rf = RandomForestRegressor(n_estimators = 1000) #, random_state = 42
rf.fit(train_features, train_labels);

# %%
predictions = rf.predict(test_features)

# %%
mae = mean_absolute_error(test_labels, predictions)
print('Mean Absolute Error:', mae)
mse_sqrt = math.sqrt(mean_squared_error(test_labels, predictions))
print('Mean Squared Error Root:', mse_sqrt)
r2 = round(r2_score(test_labels, predictions), 2)
print('R^2:', r2)
# Out:
# Mean Absolute Error: 1789.9879523809525
# Mean Squared Error Root: 2337.1468268068
# R^2: 0.53

# %%
results.append(('Random Forest' + '($R^2={:.3f}$)'.format(r2), np.array(y_test), predictions))

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
#In future implementations of the model, we can remove those variables 
# that have no importance and the performance will not suffer.
# Out:
# Variable: Length               Importance: 0.34
# Variable: PointsAjust          Importance: 0.2
# Variable: PointsNonAdjust      Importance: 0.13
# Variable: Transactions         Importance: 0.12
# Variable: Adjustment           Importance: 0.11
# Variable: Entities             Importance: 0.1

# %%
# Import matplotlib for plotting and use magic command for Jupyter Notebooks
# %matplotlib inline
# Set the style
plt.style.use('fivethirtyeight')
# list of x locations for plotting
x_values = list(range(len(importances)))
# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')
# Tick labels for x axis
plt.xticks(x_values, feature_list, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
#GRNN

# %%
y = df['Effort'].values.ravel()
X = df.drop(["Effort"], axis = 1).values
X_train, X_test, y_train, y_test = train_test_split(preprocessing.minmax_scale(X), y.reshape((-1, 1)), test_size=0.25, random_state = 42)

featnames=list(df.drop(["Effort"], axis = 1).columns)

# %%
IsotropicSelector = FS.Isotropic_selector()

start = time.time()
IsotropicSelector.relatidness(X_train, feature_names=featnames, strategy = 'ffs')
IsotropicSelector.plot_(featnames)
print('Time to complete the search [s]: ' + str(time.time() - start))
# Out:
# Searching relatidness for feature 0
# Best subset is: ['Entities', 'PointsNonAdjust', 'Adjustment', 'PointsAjust']
# Searching relatidness for feature 1
# Best subset is: ['Entities', 'PointsNonAdjust', 'PointsAjust']
# Searching relatidness for feature 2
# Best subset is: ['Transactions', 'PointsNonAdjust', 'PointsAjust']
# Searching relatidness for feature 3
# Best subset is: ['Transactions', 'Adjustment', 'PointsAjust']
# Searching relatidness for feature 4
# Best subset is: ['Length', 'Transactions', 'PointsNonAdjust', 'PointsAjust']
# Searching relatidness for feature 5
# Best subset is: ['Transactions', 'PointsNonAdjust', 'Adjustment']
# Time to complete the search [s]: 0.3678734302520752

# %%
print('Selecting the best subset of features using a forward fs strategy:')
start = time.time()
IsotropicSelector.ffs(X_train, y_train, feature_names=featnames)
print('Time to complete the search [s]: ' + str(time.time() - start))
# Out:
# Selecting the best subset of features using a forward fs strategy:
# Best subset is: ['Transactions', 'PointsNonAdjust', 'Adjustment']
# Time to complete the search [s]: 0.02291131019592285

# %%
print('Selecting the best subset of features using a backward fs strategy:')
start = time.time()
IsotropicSelector.bfs(X_train, y_train, feature_names=featnames)
print('Time to complete the search [s]: ' + str(time.time() - start))
# Out:
# Selecting the best subset of features using a backward fs strategy:
# Best subset is: ['Transactions', 'PointsNonAdjust', 'Adjustment']
# Time to complete the search [s]: 0.004988431930541992

# %%
print('Selecting the best subset of features using an exhaustive search:')
start = time.time()
IsotropicSelector.es(X_train, y_train, feature_names=featnames)
print('Time to complete the search [s]: ' + str(time.time() - start))
# Out:
# Selecting the best subset of features using an exhaustive search:
# Exploring the 63 possible combination of features...
# The best subset of features is ['Transactions', 'PointsNonAdjust', 'Adjustment']
# Time to complete the search [s]: 0.16327309608459473

# %%
print('Performing a complete feature selection from scratch:')
start = time.time()
IsotropicSelector.feat_selection(X_train, y_train, feature_names=featnames, strategy = 'ffs')
print('Time to complete the feature selection [s]: ' + str(time.time() - start))
# Out:
# Performing a complete feature selection from scratch:
# Searching relevant features...
# Best subset is: ['Transactions', 'PointsNonAdjust', 'Adjustment']
# Searching the best subset to predict feature 1
# Best subset is: ['Entities', 'PointsNonAdjust', 'PointsAjust']
# [0, 1, 4]
# Searching the best subset to predict feature 3
# Best subset is: ['Transactions', 'Adjustment', 'PointsAjust']
# [0, 2, 3]
# Searching the best subset to predict feature 4
# Best subset is: ['Length', 'Transactions', 'PointsNonAdjust', 'PointsAjust']
# [2, 4]
# Research completed!
# The relevant features are: ['Transactions', 'PointsNonAdjust', 'Adjustment']
# The redundant features are: ['Entities', 'PointsAjust', 'Length']
# The irrelevant features are: []
# Time to complete the feature selection [s]: 0.1495985984802246

# %%
best_set = IsotropicSelector.best_inSpaceIndex
X_train_BestSet = X_train[:,best_set]
X_test_BestSet = X_test[:,best_set]

# Instantiate the estimator
IGRNN = GRNN()
# Define the parameters for a GridSearch CV and fit the model
params_IGRNN = {'kernel':["RBF"],
                'sigma' : list(np.arange(0.1, 4, 0.01)),
                'calibration' : ['None']
                 }
grid_IGRNN = GridSearchCV(estimator=IGRNN,
                          param_grid=params_IGRNN,
                          scoring='neg_mean_squared_error',
                          cv=5,
                          verbose=1,
                          n_jobs = -1
                          )
grid_IGRNN.fit(X_train_BestSet, y_train.ravel())
# Use the best model to perform prediction, and compute mse
best_model = grid_IGRNN.best_estimator_
y_pred = best_model.predict(X_test_BestSet)
mse_IGRNN = MSE(y_test, y_pred)
print('MSE with IGRNN (after feature selection): ' + str(mse_IGRNN))
# Out:
# Fitting 5 folds for each of 390 candidates, totalling 1950 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    6.8s
# MSE with IGRNN (after feature selection): 9615246.100037513
# [Parallel(n_jobs=-1)]: Done 1950 out of 1950 | elapsed:    7.8s finished

# %%
mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error:', mae)
mse_sqrt = math.sqrt(mean_squared_error(y_test, y_pred))
print('Mean Squared Error Root:', mse_sqrt)
r2 = round(r2_score(y_test, y_pred), 2)
print('R^2:', r2)
# Out:
# Mean Absolute Error: 2165.5503843630136
# Mean Squared Error Root: 3100.846029721165
# R^2: 0.17

# %%
df.Effort.mode()[0]
# Out:
# 546

# %%
#Usual NN

# %%
y1 = np.array(df.Effort)

# %%
x1 = np.column_stack((df.Length,df.Transactions,df.Entities,df.PointsNonAdjust,df.Adjustment,df.PointsAjust))
x1 = sm.add_constant(x1, prepend=True)

# %%
X_train, X_val, y_train, y_val = train_test_split(x1, y1)

# %%
# The training and validation data is then scaled using MinMaxScaler:
y_train=np.reshape(y_train, (-1,1))
y_val=np.reshape(y_val, (-1,1))
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()
print(scaler_x.fit(X_train))
xtrain_scale=scaler_x.transform(X_train)
print(scaler_x.fit(X_val))
xval_scale=scaler_x.transform(X_val)
print(scaler_y.fit(y_train))
ytrain_scale=scaler_y.transform(y_train)
print(scaler_y.fit(y_val))
yval_scale=scaler_y.transform(y_val)
# Out:
# MinMaxScaler()
# MinMaxScaler()
# MinMaxScaler()
# MinMaxScaler()

# %%
model = Sequential()
model.add(Dense(7, input_dim=7, kernel_initializer='normal', activation='elu'))
model.add(Dense(1000, activation='elu'))
model.add(Dense(1, activation='linear'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 7)                 56
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              8000
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1001
# =================================================================
# Total params: 9,057
# Trainable params: 9,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])
history=model.fit(xtrain_scale, ytrain_scale, epochs=50, batch_size=150, verbose=1, validation_split=0.2)
predictions = model.predict(xval_scale)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0853 - mse: 0.0853 - mae: 0.2034 - val_loss: 0.0255 - val_mse: 0.0255 - val_mae: 0.1100
# Epoch 2/50
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0633 - mse: 0.0633 - mae: 0.1578 - val_loss: 0.0165 - val_mse: 0.0165 - val_mae: 0.0900
# Epoch 3/50
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0474 - mse: 0.0474 - mae: 0.1262 - val_loss: 0.0137 - val_mse: 0.0137 - val_mae: 0.0998
# Epoch 4/50
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0376 - mse: 0.0376 - mae: 0.1234 - val_loss: 0.0168 - val_mse: 0.0168 - val_mae: 0.1224
# Epoch 5/50
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0339 - mse: 0.0339 - mae: 0.1365 - val_loss: 0.0240 - val_mse: 0.0240 - val_mae: 0.1415
# Epoch 6/50
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0350 - mse: 0.0350 - mae: 0.1549 - val_loss: 0.0319 - val_mse: 0.0319 - val_mae: 0.1585
# Epoch 7/50
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0381 - mse: 0.0381 - mae: 0.1726 - val_loss: 0.0370 - val_mse: 0.0370 - val_mae: 0.1733
# Epoch 8/50
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1823 - val_loss: 0.0380 - val_mse: 0.0380 - val_mae: 0.1765
# Epoch 9/50
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0400 - mse: 0.0400 - mae: 0.1831 - val_loss: 0.0354 - val_mse: 0.0354 - val_mae: 0.1705
# Epoch 10/50
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0376 - mse: 0.0376 - mae: 0.1767 - val_loss: 0.0306 - val_mse: 0.0306 - val_mae: 0.1578
# Epoch 11/50
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0340 - mse: 0.0340 - mae: 0.1656 - val_loss: 0.0250 - val_mse: 0.0250 - val_mae: 0.1410
# Epoch 12/50
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0302 - mse: 0.0302 - mae: 0.1516 - val_loss: 0.0196 - val_mse: 0.0196 - val_mae: 0.1249
# Epoch 13/50
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0270 - mse: 0.0270 - mae: 0.1364 - val_loss: 0.0153 - val_mse: 0.0153 - val_mae: 0.1127
# Epoch 14/50
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0248 - mse: 0.0248 - mae: 0.1229 - val_loss: 0.0121 - val_mse: 0.0121 - val_mae: 0.1012
# Epoch 15/50
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0235 - mse: 0.0235 - mae: 0.1122 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0910
# Epoch 16/50
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0229 - mse: 0.0229 - mae: 0.1040 - val_loss: 0.0088 - val_mse: 0.0088 - val_mae: 0.0823
# Epoch 17/50
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0226 - mse: 0.0226 - mae: 0.0971 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0765
# Epoch 18/50
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0221 - mse: 0.0221 - mae: 0.0924 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0730
# Epoch 19/50
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0213 - mse: 0.0213 - mae: 0.0890 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0706
# Epoch 20/50
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0200 - mse: 0.0200 - mae: 0.0870 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0694
# Epoch 21/50
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0185 - mse: 0.0185 - mae: 0.0856 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0692
# Epoch 22/50
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0168 - mse: 0.0168 - mae: 0.0844 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0741
# Epoch 23/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0153 - mse: 0.0153 - mae: 0.0839 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0811
# Epoch 24/50
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0142 - mse: 0.0142 - mae: 0.0847 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0881
# Epoch 25/50
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0136 - mse: 0.0136 - mae: 0.0867 - val_loss: 0.0116 - val_mse: 0.0116 - val_mae: 0.0952
# Epoch 26/50
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0135 - mse: 0.0135 - mae: 0.0883 - val_loss: 0.0130 - val_mse: 0.0130 - val_mae: 0.1012
# Epoch 27/50
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0136 - mse: 0.0136 - mae: 0.0887 - val_loss: 0.0138 - val_mse: 0.0138 - val_mae: 0.1035
# Epoch 28/50
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0136 - mse: 0.0136 - mae: 0.0878 - val_loss: 0.0136 - val_mse: 0.0136 - val_mae: 0.1018
# Epoch 29/50
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0134 - mse: 0.0134 - mae: 0.0858 - val_loss: 0.0126 - val_mse: 0.0126 - val_mae: 0.0963
# Epoch 30/50
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0129 - mse: 0.0129 - mae: 0.0832 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0889
# Epoch 31/50
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0123 - mse: 0.0123 - mae: 0.0804 - val_loss: 0.0094 - val_mse: 0.0094 - val_mae: 0.0810
# Epoch 32/50
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0119 - mse: 0.0119 - mae: 0.0798 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0759
# Epoch 33/50
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0117 - mse: 0.0117 - mae: 0.0798 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0722
# Epoch 34/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0119 - mse: 0.0119 - mae: 0.0814 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0694
# Epoch 35/50
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0122 - mse: 0.0122 - mae: 0.0835 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0679
# Epoch 36/50
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0124 - mse: 0.0124 - mae: 0.0853 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0678
# Epoch 37/50
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0125 - mse: 0.0125 - mae: 0.0860 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0690
# Epoch 38/50
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0123 - mse: 0.0123 - mae: 0.0853 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0713
# Epoch 39/50
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0121 - mse: 0.0121 - mae: 0.0838 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0743
# Epoch 40/50
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0119 - mse: 0.0119 - mae: 0.0824 - val_loss: 0.0086 - val_mse: 0.0086 - val_mae: 0.0774
# Epoch 41/50
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0118 - mse: 0.0118 - mae: 0.0815 - val_loss: 0.0096 - val_mse: 0.0096 - val_mae: 0.0802
# Epoch 42/50
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0118 - mse: 0.0118 - mae: 0.0808 - val_loss: 0.0104 - val_mse: 0.0104 - val_mae: 0.0828
# Epoch 43/50
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0119 - mse: 0.0119 - mae: 0.0803 - val_loss: 0.0107 - val_mse: 0.0107 - val_mae: 0.0842
# Epoch 44/50
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0119 - mse: 0.0119 - mae: 0.0801 - val_loss: 0.0107 - val_mse: 0.0107 - val_mae: 0.0841
# Epoch 45/50
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0117 - mse: 0.0117 - mae: 0.0798 - val_loss: 0.0103 - val_mse: 0.0103 - val_mae: 0.0831
# Epoch 46/50
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0115 - mse: 0.0115 - mae: 0.0794 - val_loss: 0.0097 - val_mse: 0.0097 - val_mae: 0.0819
# Epoch 47/50
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0113 - mse: 0.0113 - mae: 0.0788 - val_loss: 0.0091 - val_mse: 0.0091 - val_mae: 0.0805
# Epoch 48/50
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0112 - mse: 0.0112 - mae: 0.0786 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0791
# Epoch 49/50
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0111 - mse: 0.0111 - mae: 0.0789 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0782
# Epoch 50/50
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0111 - mse: 0.0111 - mae: 0.0790 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0778

# %%
print(history.history.keys())
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'mse', 'mae', 'val_loss', 'val_mse', 'val_mae'])

# %%
predictions = scaler_y.inverse_transform(predictions)

# %%
mae = mean_absolute_error(y_val, predictions)
print('Mean Absolute Error:', mae)
mse_sqrt = math.sqrt(mean_squared_error(y_val, predictions))
print('Mean Squared Error Root:', mse_sqrt)
r2 = round(r2_score(y_val, predictions), 2)
print('R^2:', r2)
# Out:
# Mean Absolute Error: 2451.9476812453495
# Mean Squared Error Root: 3378.6998024123804
# R^2: -0.07

# %%
np.mean(y_val)
# Out:
# 4343.666666666667

# %%
np.mean(predictions)
# Out:
# 3564.9453

# %%
# RBFN

# %%
class RBFLayer(Layer):
    def __init__(self, units, gamma, **kwargs):
        super(RBFLayer, self).__init__(**kwargs)
        self.units = units
        self.gamma = K.cast_to_floatx(gamma)

    def build(self, input_shape):
#         print(input_shape)
#         print(self.units)
        self.mu = self.add_weight(name='mu',
                                  shape=(int(input_shape[1]), self.units),
                                  initializer='uniform',
                                  trainable=True)
        super(RBFLayer, self).build(input_shape)

    def call(self, inputs):
        diff = K.expand_dims(inputs) - self.mu
        l2 = K.sum(K.pow(diff, 2), axis=1)
        res = K.exp(-1 * self.gamma * l2)
        return res

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.units)

# %%
model = Sequential()
#model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(7, input_dim=7, kernel_initializer='normal', activation='relu'))
model.add(RBFLayer(100, 0.9))
model.add(Dense(1, activation='sigmoid', name='foo'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 7)                 56
# _________________________________________________________________
# rbf_layer (RBFLayer)         (None, 100)               700
# _________________________________________________________________
# foo (Dense)                  (None, 1)                 101
# =================================================================
# Total params: 857
# Trainable params: 857
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='mse', metrics=['mse','mae'])

# %%
history=model.fit(xtrain_scale, ytrain_scale, epochs=30, batch_size=256, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/30
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0111 - mse: 0.0111 - mae: 0.0790 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0781
# Epoch 2/30
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0110 - mse: 0.0110 - mae: 0.0788 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0790
# Epoch 3/30
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0109 - mse: 0.0109 - mae: 0.0785 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0804
# Epoch 4/30
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0109 - mse: 0.0109 - mae: 0.0783 - val_loss: 0.0090 - val_mse: 0.0090 - val_mae: 0.0821
# Epoch 5/30
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0108 - mse: 0.0108 - mae: 0.0781 - val_loss: 0.0095 - val_mse: 0.0095 - val_mae: 0.0838
# Epoch 6/30
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0107 - mse: 0.0107 - mae: 0.0780 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0859
# Epoch 7/30
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0107 - mse: 0.0107 - mae: 0.0779 - val_loss: 0.0105 - val_mse: 0.0105 - val_mae: 0.0876
# Epoch 8/30
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0107 - mse: 0.0107 - mae: 0.0779 - val_loss: 0.0107 - val_mse: 0.0107 - val_mae: 0.0887
# Epoch 9/30
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0107 - mse: 0.0107 - mae: 0.0779 - val_loss: 0.0107 - val_mse: 0.0107 - val_mae: 0.0890
# Epoch 10/30
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0107 - mse: 0.0107 - mae: 0.0778 - val_loss: 0.0106 - val_mse: 0.0106 - val_mae: 0.0887
# Epoch 11/30
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0106 - mse: 0.0106 - mae: 0.0778 - val_loss: 0.0103 - val_mse: 0.0103 - val_mae: 0.0879
# Epoch 12/30
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0106 - mse: 0.0106 - mae: 0.0778 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0869
# Epoch 13/30
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0106 - mse: 0.0106 - mae: 0.0777 - val_loss: 0.0097 - val_mse: 0.0097 - val_mae: 0.0860
# Epoch 14/30
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0105 - mse: 0.0105 - mae: 0.0777 - val_loss: 0.0096 - val_mse: 0.0096 - val_mae: 0.0854
# Epoch 15/30
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0105 - mse: 0.0105 - mae: 0.0776 - val_loss: 0.0095 - val_mse: 0.0095 - val_mae: 0.0852
# Epoch 16/30
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0105 - mse: 0.0105 - mae: 0.0776 - val_loss: 0.0096 - val_mse: 0.0096 - val_mae: 0.0855
# Epoch 17/30
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0105 - mse: 0.0105 - mae: 0.0775 - val_loss: 0.0097 - val_mse: 0.0097 - val_mae: 0.0863
# Epoch 18/30
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0104 - mse: 0.0104 - mae: 0.0774 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0873
# Epoch 19/30
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0104 - mse: 0.0104 - mae: 0.0773 - val_loss: 0.0103 - val_mse: 0.0103 - val_mae: 0.0886
# Epoch 20/30
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0772 - val_loss: 0.0107 - val_mse: 0.0107 - val_mae: 0.0898
# Epoch 21/30
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0772 - val_loss: 0.0109 - val_mse: 0.0109 - val_mae: 0.0908
# Epoch 22/30
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0771 - val_loss: 0.0111 - val_mse: 0.0111 - val_mae: 0.0914
# Epoch 23/30
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0770 - val_loss: 0.0112 - val_mse: 0.0112 - val_mae: 0.0917
# Epoch 24/30
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0769 - val_loss: 0.0111 - val_mse: 0.0111 - val_mae: 0.0916
# Epoch 25/30
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0102 - mse: 0.0102 - mae: 0.0768 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0912
# Epoch 26/30
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0102 - mse: 0.0102 - mae: 0.0768 - val_loss: 0.0109 - val_mse: 0.0109 - val_mae: 0.0907
# Epoch 27/30
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0102 - mse: 0.0102 - mae: 0.0767 - val_loss: 0.0108 - val_mse: 0.0108 - val_mae: 0.0903
# Epoch 28/30
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0102 - mse: 0.0102 - mae: 0.0768 - val_loss: 0.0107 - val_mse: 0.0107 - val_mae: 0.0901
# Epoch 29/30
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0101 - mse: 0.0101 - mae: 0.0768 - val_loss: 0.0108 - val_mse: 0.0108 - val_mae: 0.0903
# Epoch 30/30
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0101 - mse: 0.0101 - mae: 0.0768 - val_loss: 0.0109 - val_mse: 0.0109 - val_mae: 0.0907

# %%
predictions = model.predict(xval_scale)
# Out:
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020B10A4FD30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print(history.history.keys())
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'mse', 'mae', 'val_loss', 'val_mse', 'val_mae'])

# %%
predictions = scaler_y.inverse_transform(predictions)

# %%
mae = mean_absolute_error(y_val, predictions)
print('Mean Absolute Error:', mae)
mse_sqrt = math.sqrt(mean_squared_error(y_val, predictions))
print('Mean Squared Error Root:', mse_sqrt)
r2 = round(r2_score(y_val, predictions), 2)
print('R^2:', r2)
print(r2)
# Out:
# Mean Absolute Error: 3293.4040876116073
# Mean Squared Error Root: 4543.778700592955
# R^2: 0.2
# 0.2

# %%
np.mean(y_val)
# Out:
# 4760.0

# %%
np.mean(predictions)
# Out:
# 9004.807

# %%
#Ensembles

# %%
#Usual Imports
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import VotingRegressor,GradientBoostingRegressor,HistGradientBoostingRegressor,StackingRegressor
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error,accuracy_score
from sklearn.ensemble import AdaBoostRegressor,BaggingRegressor,ExtraTreesRegressor
from xgboost import XGBRegressor
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential
from keras.metrics import RootMeanSquaredError
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import r2_score

# %%
#Scikit-learn Models
lin_reg= LinearRegression()
rnd_reg = RandomForestRegressor(n_estimators=100, random_state=42)
svr_reg = SVR(gamma="scale")
#Keras Model
def build_nn():
    model= Sequential(
                [Dense(512,activation='selu',input_shape=[7]),
                 Dense(256,activation='selu'),
                 Dropout(0.2),
                 Dense(128,activation='selu'),
                 Dense(64,activation='selu'),
                 Dense(1)
    ])
    model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['RootMeanSquaredError'])
    return model

# %%
keras_reg = tf.keras.wrappers.scikit_learn.KerasRegressor(
                build_nn,epochs=1000,verbose=False)
keras_reg._estimator_type = "regressor"

# %%
voting_reg = VotingRegressor(
             estimators=[('lr', lin_reg), 
                         ('rf', rnd_reg),
                         ('svr', svr_reg),
                         ('Dense',keras_reg)])

# %%
#Default: RidgeCV
st_reg=StackingRegressor(
        estimators=[('lr', lin_reg),
                    ('rf', rnd_reg),
                    ('svr', svr_reg),
                    ('Dense',keras_reg)])

#final_estimator=LinearRegression()

# %%
target = df['Effort']
predictors = ['Length', 'Effort', 'Transactions', 'Entities', 'PointsNonAdjust',
       'Adjustment', 'PointsAjust']
X_train, X_test, y_train, y_test = train_test_split(df, target, test_size=0.2)

# %%
for reg in (lin_reg, rnd_reg, svr_reg,keras_reg, voting_reg, st_reg):
    reg.fit(X_train, y_train)
    y_pred = reg.predict(X_test)
    print(reg.__class__.__name__)
    mae = mean_absolute_error(y_test, y_pred)
    print('Mean Absolute Error:', mae)
    mse_sqrt = math.sqrt(mean_squared_error(y_test, y_pred))
    print('Mean Squared Error Root:', mse_sqrt)
    r2 = round(r2_score(y_test, y_pred), 2)
    print('R^2:', r2)
    print(r2)
# Out:
# LinearRegression
# Mean Absolute Error: 1.0699937667916803e-12
# Mean Squared Error Root: 1.4322099890797845e-12
# R^2: 1.0
# 1.0
# RandomForestRegressor
# Mean Absolute Error: 126.51294117647046
# Mean Squared Error Root: 279.8979626473146
# R^2: 0.99
# 0.99
# SVR
# Mean Absolute Error: 2171.374844838261
# Mean Squared Error Root: 3022.263926143801
# R^2: -0.02
# -0.02
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002D89B9445E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# KerasRegressor
# Mean Absolute Error: 637.5938612994025
# Mean Squared Error Root: 844.2928639132141
# R^2: 0.92
# 0.92
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002D895E103A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# VotingRegressor
# Mean Absolute Error: 592.5238909178094
# Mean Squared Error Root: 815.7264451353673
# R^2: 0.93
# 0.93
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002D8975378B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002D896107160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002D89A03DEE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002D898AB11F0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002D89B980AF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002D89A0F6430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# StackingRegressor
# Mean Absolute Error: 0.07924387759826726
# Mean Squared Error Root: 0.08930142754248077
# R^2: 1.0
# 1.0
